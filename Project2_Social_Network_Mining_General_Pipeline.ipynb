# %%
import networkx as nx
import numpy as np
import os
import time
import pandas as pd
import matplotlib.pyplot as plt
import itertools
from itertools import chain
from collections import defaultdict
from gensim.models import Word2Vec
from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score
import tqdm

# %%
print(np.__version__)
print(pd.__version__)

# %% [markdown]
# # Pipeline

# %% [markdown]
# ### Data Loader

# %% [markdown]
# We need to load networks into memory. Usually networks are organized as pairs of nodes. And sometimes different edges have different weights. Hence, we use networkx.DiGraph to store such structure information and attributes.

# %%
def load_data(file_name):
    """
    read edges from an edge file
    """
    edges = list()
    df = pd.read_csv(file_name)
    for idx, row in df.iterrows():
        user_id, friends = row["user_id"], eval(row["friends"])
        for friend in friends:
            # add each friend relation as an edge
            edges.append((user_id, friend))
    edges = sorted(edges)
    
    return edges

def load_test_data(file_name):
    """
    read edges from an edge file
    """
    edges = list()
    scores = list()
    df = pd.read_csv(file_name)
    for idx, row in df.iterrows():
        edges.append((row["src"], row["dst"]))
        scores.append(row["score"])
    #edges = sorted(edges)
    
    return edges,scores

def generate_false_edges(true_edges, num_false_edges=5):
    """
    generate false edges given true edges
    """
    nodes = list(set(chain.from_iterable(true_edges)))
    N = len(nodes)
    true_edges = set(true_edges)
    print(N, len(true_edges))
    false_edges = set()
    
    while len(false_edges) < num_false_edges:
        # randomly sample two different nodes and check whether the pair exisit or not
        src, dst = nodes[int(np.random.rand() * N)], nodes[int(np.random.rand() * N)]
        if src != dst and (src, dst) not in true_edges and (src, dst) not in false_edges:
            false_edges.add((src, dst))
    false_edges = sorted(false_edges)
    
    return false_edges

def construct_graph_from_edges(edges):
    """
    generate a directed graph object given true edges
    DiGraph documentation: https://networkx.github.io/documentation/stable/reference/classes/digraph.html
    """
    # convert a list of edges {(u, v)} to a list of edges with weights {(u, v, w)}
    edge_weight = defaultdict(float)
    for e in edges:
        edge_weight[e] += 1.0
    weighed_edge_list = list()
    for e in sorted(edge_weight.keys()):
        weighed_edge_list.append((e[0], e[1], edge_weight[e]))
        
    graph = nx.DiGraph()
    graph.add_weighted_edges_from(weighed_edge_list)
    
    print("number of nodes:", graph.number_of_nodes())
    print("number of edges:", graph.number_of_edges())
    
    return graph

# %% [markdown]
# ### Random Walk Generator

# %% [markdown]
# Random walk generators or random walkers yield random walks that contain both local and higher-order neighborhood information. However, naive non-uniform sampling is very slow, which requires O(n) time complexity. Here alias sampling can reduce the time complexity to O(1) with O(n) space. If you are interested, please see the following blog.

# %%
def alias_setup(probs):
    """
    compute utility lists for non-uniform sampling from discrete distributions.
    details: https://lips.cs.princeton.edu/the-alias-method-efficient-sampling-with-many-discrete-outcomes/
    """
    K = len(probs)
    q = np.zeros(K)
    J = np.zeros(K, dtype=int)

    smaller = list()
    larger = list()
    for kk, prob in enumerate(probs):
        q[kk] = K * prob
        if q[kk] < 1.0:
            smaller.append(kk)
        else:
            larger.append(kk)

    while len(smaller) > 0 and len(larger) > 0:
        small = smaller.pop()
        large = larger.pop()

        J[small] = large
        q[large] = q[large] + q[small] - 1.0
        if q[large] < 1.0:
            smaller.append(large)
        else:
            larger.append(large)

    return J, q

def get_alias_node(graph, node):
    """
    get the alias node setup lists for a given node.
    """
    # get the unnormalized probabilities with the first-order information
    unnormalized_probs = list()
    for nbr in graph.neighbors(node):
        unnormalized_probs.append(graph[node][nbr]["weight"])
    unnormalized_probs = np.array(unnormalized_probs)
    if len(unnormalized_probs) > 0:
        normalized_probs = unnormalized_probs / unnormalized_probs.sum()
    else:
        normalized_probs = unnormalized_probs
        
    return alias_setup(normalized_probs)
    
def get_alias_edge(graph, src, dst, p=1, q=1):
    """
    get the alias edge setup lists for a given edge.
    """
    # get the unnormalized probabilities with the second-order information
    unnormalized_probs = list()
    for dst_nbr in graph.neighbors(dst):
        if dst_nbr == src: # distance is 0
            unnormalized_probs.append(graph[dst][dst_nbr]["weight"]/p)
        elif graph.has_edge(dst_nbr, src): # distance is 1
            unnormalized_probs.append(graph[dst][dst_nbr]["weight"])
        else: # distance is 2
            unnormalized_probs.append(graph[dst][dst_nbr]["weight"]/q)
    unnormalized_probs = np.array(unnormalized_probs)
    if len(unnormalized_probs) > 0:
        normalized_probs = unnormalized_probs / unnormalized_probs.sum()
    else:
        normalized_probs = unnormalized_probs

    return alias_setup(normalized_probs)

def preprocess_transition_probs(graph, p=1, q=1):
    """
    preprocess transition probabilities for guiding the random walks.
    """
    alias_nodes = dict()
    for node in graph.nodes():
        alias_nodes[node] = get_alias_node(graph, node)

    alias_edges = dict()
    for edge in graph.edges():
        alias_edges[edge] = get_alias_edge(graph, edge[0], edge[1], p=p, q=q)

    return alias_nodes, alias_edges

# %% [markdown]
# The difference between DeepWalk and node2vec is how to generate random walks. The former only consider the first-order information while the latter also involves the second-order information.

# %%
def alias_draw(J, q):
    """
    draw sample from a non-uniform discrete distribution using alias sampling.
    """
    K = len(J)

    kk = int(np.floor(np.random.rand() * K))
    if np.random.rand() < q[kk]:
        return kk
    else:
        return J[kk]


# helper function to generate the long random walk as desired
def fallback(walk, fetch_last_num=1):
    if len(walk) > fetch_last_num:
        walk.pop()
        fetched = []
        for i in range(fetch_last_num):
            fetched.append(walk[-1-i])
        return walk, fetched
    else:
        return [], [None for _ in range(fetch_last_num)]

def generate_first_order_random_walk(graph, alias_nodes, 
                                     walk_length=10, start_node=None, verbose=False, max_trails=10):
    """
    simulate a random walk starting from start node and considering the first order information.
    max_trials: set the max trials to be one for standard random walk. Larger max_trails will make the generated biased.
    """
    if start_node == None:
        start_node = np.random.choice(graph.nodes())
    walk = [start_node]
    cur = start_node
    num_tried = 0
    
    ########## begin ##########
    while len(walk) < walk_length:
        cur_nbrs = list(graph.neighbors(cur))
        if len(cur_nbrs) > 0: # if we can sample next nodes
            # sample the next node based on alias_nodes
            cur = cur_nbrs[alias_draw(*alias_nodes[cur])]
            walk.append(cur)
        else: # if we can't do that
            num_tried += 1
            if num_tried >= max_trails:
                break

            walk, fetched = fallback(walk, fetch_last_num=1)
            cur = fetched[0]
            if len(walk) == 0: # if falls back to the empty walk
                start_node = np.random.choice(graph.nodes())
                walk = [start_node]
                cur = start_node
    ########## end ##########

    if verbose: 
        print(f'walk of lenght {len(walk)} generated with {num_tried} trails')
    return walk
    
def generate_second_order_random_walk(graph, alias_nodes, alias_edges, 
                                      walk_length=10, start_node=None, verbose=False, max_trails=10):
    """
    simulate a random walk starting from start node and considering the second order information.
    """
    if start_node == None:
        start_node = np.random.choice(graph.nodes())
    walk = [start_node]
    
    prev = None
    cur = start_node
    num_tried = 0

    ########## begin ##########
    while len(walk) < walk_length:
        cur_nbrs = list(graph.neighbors(cur))
        if len(cur_nbrs) > 0:
            if prev is None:
                # sample the next node based on alias_nodes
                prev, cur = cur, cur_nbrs[alias_draw(*alias_nodes[cur])]
            else:
                # sample the next node based on alias_edges
                prev, cur = cur, cur_nbrs[alias_draw(*alias_edges[(prev, cur)])]
            walk.append(cur)
        else:
            num_tried += 1
            if num_tried >= max_trails:
                break
            walk, (cur, prev) = fallback(walk, fetch_last_num=2)
            if len(walk) == 0:
                start_node = np.random.choice(graph.nodes())
                walk = [start_node]
                cur = start_node
                prev = None
    ########## end ##########
    if verbose: 
        print(f'walk of lenght {len(walk)} generated with {num_tried} trails')
    return walk

# %% [markdown]
# ### Network Embedding Algorithms

# %%
def build_deepwalk(graph, alias_nodes, node_dim=10, num_walks=10, walk_length=10):
    """
    build a deepwalk model
    """
    print("building a DeepWalk model...", end="\t")
    st = time.time()
    np.random.seed(0)
    nodes = list(graph.nodes())
    walks = list()
    # generate random walks
    for walk_iter in range(num_walks):
        np.random.shuffle(nodes)
        for node in nodes:
            walks.append(generate_first_order_random_walk(
                graph, alias_nodes, walk_length=walk_length, start_node=node))
        
    walk_lens = [len(w) for w in walks]
    if len(walk_lens) > 0:
        avg_walk_len = sum(walk_lens) / len(walk_lens)
    else:
        avg_walk_len = 0.0
    print("number of walks: %d\taverage walk length: %.4f" % (len(walks), avg_walk_len), end="\t")
    
    # train a skip-gram model for these walks
    model = Word2Vec(walks, vector_size=node_dim, window=3, min_count=0, sg=1, workers=os.cpu_count(), epochs=10)
    print("training time: %.4f" % (time.time()-st))
    
    return model

def build_node2vec(graph, alias_nodes, alias_edges, node_dim=10, num_walks=10, walk_length=10):
    """
    build a node2vec model
    """
    print("building a node2vec model...", end="\t")
    st = time.time()
    np.random.seed(0)
    nodes = list(graph.nodes())
    walks = list()
    # generate random walks
    for walk_iter in range(num_walks):
        np.random.shuffle(nodes)
        for node in nodes:
            walks.append(generate_second_order_random_walk(
                graph, alias_nodes, alias_edges, walk_length=walk_length, start_node=node))
            
    walk_lens = [len(w) for w in walks]
    if len(walk_lens) > 0:
        avg_walk_len = sum(walk_lens) / len(walk_lens)
    else:
        avg_walk_len = 0.0    
    print("number of walks: %d\taverage walk length: %.4f" % (len(walks), avg_walk_len), end="\t")
    
    # train a skip-gram model for these walks
    model = Word2Vec(walks, vector_size=node_dim, window=3, min_count=0, sg=1, workers=os.cpu_count(), epochs=10)
    print("training time: %.4f" % (time.time()-st))
    
    return model

# %% [markdown]
# ### Scorer

# %%
def get_cosine_sim(model, u, v):
    """
    get the cosine similarity between two nodes
    """
    try:
        u = model.wv[u]
        v = model.wv[v]
        return np.dot(u, v) / (np.linalg.norm(u) * np.linalg.norm(v))
    except:
        return 0.5

def get_auc_score(model, true_edges, false_edges):
    """
    get the auc score
    """
    y_true = [1] * len(true_edges) + [0] * len(false_edges)
    
    y_score = list()
    for e in true_edges:
        y_score.append(get_cosine_sim(model, e[0], e[1]))
    for e in false_edges:
        y_score.append(get_cosine_sim(model, e[0], e[1]))
    
    return roc_auc_score(y_true, y_score)

def get_auc_score_test(model, edges,scores):
    """
    get the auc score
    """
    y_true = scores
    
    y_score = list()
    for e in edges:
        y_score.append(get_cosine_sim(model, e[0], e[1]))
    
    return roc_auc_score(y_true, y_score)


def write_pred(file_name, edges, scores):
    df = pd.DataFrame()
    df["src"] = [e[0] for e in edges]
    df["dst"] = [e[1] for e in edges]
    df["score"] = scores
    df.to_csv(file_name, index=False)
    
    



def write_valid_ans(file_name, edges, scores):
    df = pd.DataFrame()
    df["src"] = [e[0] for e in edges]
    df["dst"] = [e[1] for e in edges]
    df["score"] = scores
    df.to_csv(file_name, index=False)

# %% [markdown]
# ### Try them over a Real-life Network

# %% [markdown]
# Firstly, we need to load edges into memory and use the networkx.DiGraph structure to store the graph.

# %%
train_file = "data/train.csv"
valid_file = "data/valid.csv"
test_file = "data/test.csv"

np.random.seed(2023)
train_edges = load_data(train_file)
graph = construct_graph_from_edges(train_edges)
valid_edges = load_data(valid_file)
false_edges = generate_false_edges(train_edges+valid_edges, 40000-len(valid_edges))
test_edges,test_scores = load_test_data(test_file)

# %% [markdown]
# After that, we can use preprocess transition probabilities with the help of alias sampling.

# %%
alias_nodes, alias_edges = preprocess_transition_probs(graph, p=1, q=1)

# %% [markdown]
# We can use random walk generators to generate random walks.

# %% [markdown]
# Let's try to generate a first-order random walk and a second-order random walk.

# %%
generate_first_order_random_walk(graph, alias_nodes=alias_nodes,
                                 start_node="N6ZTMIue-2b30CJv2tyPGg", walk_length=10)

# %%
generate_second_order_random_walk(graph, alias_nodes=alias_nodes, alias_edges=alias_edges,
                                  start_node="N6ZTMIue-2b30CJv2tyPGg", walk_length=10)

# %% [markdown]
# And we can build a DeepWalk model and a node2vec model. Here we set p=q=0.5 so that the walker will not go very far away from the start node.

# %%
model = build_deepwalk(graph, alias_nodes, node_dim=10, num_walks=10, walk_length=10)

# %%
model = build_node2vec(graph, alias_nodes, alias_edges, node_dim=10, num_walks=10, walk_length=10)

# %% [markdown]
# Let's see the node embeddings of three nodes, and cosine similarities of two edges.

# %%
print("node embedding (\"N6ZTMIue-2b30CJv2tyPGg\"):",
      model.wv["N6ZTMIue-2b30CJv2tyPGg"])
print("node embedding (\"N7E-CfqdME28dakWdEKNvw\"):",
      model.wv["N7E-CfqdME28dakWdEKNvw"])
print("node embedding (\"MmlJSLDg-IFaeXb5wdJbgg\"):",
      model.wv.vectors[model.wv.index_to_key.index("MmlJSLDg-IFaeXb5wdJbgg")])
print("true edge (\"N6ZTMIue-2b30CJv2tyPGg\", \"N7E-CfqdME28dakWdEKNvw\"):",
      get_cosine_sim(model, "N6ZTMIue-2b30CJv2tyPGg", "N7E-CfqdME28dakWdEKNvw"))
print("false edge (\"N6ZTMIue-2b30CJv2tyPGg\", \"MmlJSLDg-IFaeXb5wdJbgg\"):",
      get_cosine_sim(model, "N6ZTMIue-2b30CJv2tyPGg", "MmlJSLDg-IFaeXb5wdJbgg"))

# %% [markdown]
# # Link Prediction

# %% [markdown]
# We can train the model with different parameters and test the model on the validation set. Please show your parameter search process and analysis in your code, and visualization tools (Heatmap, etc.) are recommended to make your analysis clear.

# %%
np.random.seed(0)

# node_dim = 300 # TODO
# num_walks = 100 # TODO
# walk_length = 30 # TODO

# deepwalk_auc_scores = dict()
# print("node dim: %d,\tnum_walks: %d,\twalk_length: %d" % (node_dim, num_walks, walk_length), end="\t")
# model = build_deepwalk(graph, alias_nodes, 
#                          node_dim=node_dim, num_walks=num_walks, walk_length=walk_length)
# deepwalk_auc_scores[(node_dim, num_walks, walk_length,'valid')] = get_auc_score(model, valid_edges, false_edges)
# print("valid auc: %.4f" % (deepwalk_auc_scores[(node_dim, num_walks, walk_length,'valid')]))

# %%
np.random.seed(0)

node_dim = [10, 20, 50, 100] 
num_walks = [10, 20, 50] 
walk_length = [10, 20, 50] 
p = [0.25, 0.5, 1.25]
q = [0.25, 0.5, 1.25] 

node2vec_auc_scores = dict()

for node_dim_, num_walks_, walk_length_, p_, q_ in list(itertools.product(node_dim, num_walks, walk_length, p, q)):
    print("node dim: %d,\tnum_walks: %d,\twalk_length: %d,\tp: %.2f,\tq: %.2f" % (node_dim_, num_walks_, walk_length_, p_, q_))
    alias_nodes, alias_edges = preprocess_transition_probs(graph, p=p_, q=q_)
    model = build_node2vec(graph, alias_nodes, alias_edges, node_dim=node_dim_, num_walks=num_walks_, walk_length=walk_length_)
    node2vec_auc_scores[(node_dim_, num_walks_, walk_length_, p_, q_,'valid')] = get_auc_score(model, valid_edges, false_edges)
    print("valid auc: %.4f" % (node2vec_auc_scores[(node_dim_, num_walks_, walk_length_, p_, q_,'valid')]))
# Out:
# building a node2vec model...	number of walks: 83340	average walk length: 9.9913	training time: 12.3372
# valid auc: 0.9283
# node dim: 10,	num_walks: 10,	walk_length: 10,	p: 0.25,	q: 0.50
# building a node2vec model...	number of walks: 83340	average walk length: 9.9910	training time: 12.1756
# valid auc: 0.9276
# node dim: 10,	num_walks: 10,	walk_length: 10,	p: 0.25,	q: 1.25
# building a node2vec model...	number of walks: 83340	average walk length: 9.9922	training time: 12.1512
# valid auc: 0.9291
# node dim: 10,	num_walks: 10,	walk_length: 10,	p: 0.50,	q: 0.25
# building a node2vec model...	number of walks: 83340	average walk length: 9.9883	training time: 12.2833
# valid auc: 0.9265
# node dim: 10,	num_walks: 10,	walk_length: 10,	p: 0.50,	q: 0.50
# building a node2vec model...	number of walks: 83340	average walk length: 9.9904	training time: 12.2411
# valid auc: 0.9273
# node dim: 10,	num_walks: 10,	walk_length: 10,	p: 0.50,	q: 1.25
# building a node2vec model...	number of walks: 83340	average walk length: 9.9906	training time: 12.3708
# valid auc: 0.9271
# node dim: 10,	num_walks: 10,	walk_length: 10,	p: 1.25,	q: 0.25
# building a node2vec model...	number of walks: 83340	average walk length: 9.9836	training time: 12.2341
# valid auc: 0.9266
# node dim: 10,	num_walks: 10,	walk_length: 10,	p: 1.25,	q: 0.50
# building a node2vec model...	number of walks: 83340	average walk length: 9.9875	training time: 12.2807
# valid auc: 0.9249
# node dim: 10,	num_walks: 10,	walk_length: 10,	p: 1.25,	q: 1.25
# building a node2vec model...	number of walks: 83340	average walk length: 9.9899	training time: 12.2088
# valid auc: 0.9276
# node dim: 10,	num_walks: 10,	walk_length: 20,	p: 0.25,	q: 0.25
# building a node2vec model...	number of walks: 83340	average walk length: 19.9599	training time: 16.6250
# valid auc: 0.9307
# node dim: 10,	num_walks: 10,	walk_length: 20,	p: 0.25,	q: 0.50
# building a node2vec model...	number of walks: 83340	average walk length: 19.9671	training time: 16.4267
# valid auc: 0.9307
# node dim: 10,	num_walks: 10,	walk_length: 20,	p: 0.25,	q: 1.25
# building a node2vec model...	number of walks: 83340	average walk length: 19.9704	training time: 16.5060
# valid auc: 0.9314
# node dim: 10,	num_walks: 10,	walk_length: 20,	p: 0.50,	q: 0.25
# building a node2vec model...	number of walks: 83340	average walk length: 19.9485	training time: 16.6154
# valid auc: 0.9293
# node dim: 10,	num_walks: 10,	walk_length: 20,	p: 0.50,	q: 0.50
# building a node2vec model...	number of walks: 83340	average walk length: 19.9600	training time: 16.6649
# valid auc: 0.9313
# node dim: 10,	num_walks: 10,	walk_length: 20,	p: 0.50,	q: 1.25
# building a node2vec model...	number of walks: 83340	average walk length: 19.9677	training time: 16.4073
# valid auc: 0.9307
# node dim: 10,	num_walks: 10,	walk_length: 20,	p: 1.25,	q: 0.25
# building a node2vec model...	number of walks: 83340	average walk length: 19.9289	training time: 16.6277
# valid auc: 0.9306
# node dim: 10,	num_walks: 10,	walk_length: 20,	p: 1.25,	q: 0.50
# building a node2vec model...	number of walks: 83340	average walk length: 19.9497	training time: 16.7259
# valid auc: 0.9310
# node dim: 10,	num_walks: 10,	walk_length: 20,	p: 1.25,	q: 1.25
# building a node2vec model...	number of walks: 83340	average walk length: 19.9636	training time: 16.7503
# valid auc: 0.9311
# node dim: 10,	num_walks: 10,	walk_length: 50,	p: 0.25,	q: 0.25
# building a node2vec model...	number of walks: 83340	average walk length: 49.7593	training time: 30.1661
# valid auc: 0.9280
# node dim: 10,	num_walks: 10,	walk_length: 50,	p: 0.25,	q: 0.50
# building a node2vec model...	number of walks: 83340	average walk length: 49.8189	training time: 29.9283
# valid auc: 0.9276
# node dim: 10,	num_walks: 10,	walk_length: 50,	p: 0.25,	q: 1.25
# building a node2vec model...	number of walks: 83340	average walk length: 49.8485	training time: 29.7075
# valid auc: 0.9266
# node dim: 10,	num_walks: 10,	walk_length: 50,	p: 0.50,	q: 0.25
# building a node2vec model...	number of walks: 83340	average walk length: 49.7103	training time: 30.1081
# valid auc: 0.9273
# node dim: 10,	num_walks: 10,	walk_length: 50,	p: 0.50,	q: 0.50
# building a node2vec model...	number of walks: 83340	average walk length: 49.7449	training time: 30.1345
# valid auc: 0.9265
# node dim: 10,	num_walks: 10,	walk_length: 50,	p: 0.50,	q: 1.25
# building a node2vec model...	number of walks: 83340	average walk length: 49.8280	training time: 29.8589
# valid auc: 0.9269
# node dim: 10,	num_walks: 10,	walk_length: 50,	p: 1.25,	q: 0.25
# building a node2vec model...	number of walks: 83340	average walk length: 49.6407	training time: 30.1754
# valid auc: 0.9274
# node dim: 10,	num_walks: 10,	walk_length: 50,	p: 1.25,	q: 0.50
# building a node2vec model...	number of walks: 83340	average walk length: 49.6884	training time: 30.3386
# valid auc: 0.9278
# node dim: 10,	num_walks: 10,	walk_length: 50,	p: 1.25,	q: 1.25
# building a node2vec model...	number of walks: 83340	average walk length: 49.7727	training time: 29.9236
# valid auc: 0.9287
# node dim: 10,	num_walks: 20,	walk_length: 10,	p: 0.25,	q: 0.25
# building a node2vec model...	number of walks: 166680	average walk length: 9.9911	training time: 23.8649
# valid auc: 0.9302
# node dim: 10,	num_walks: 20,	walk_length: 10,	p: 0.25,	q: 0.50
# building a node2vec model...	number of walks: 166680	average walk length: 9.9912	training time: 23.9586
# valid auc: 0.9313
# node dim: 10,	num_walks: 20,	walk_length: 10,	p: 0.25,	q: 1.25
# building a node2vec model...	number of walks: 166680	average walk length: 9.9925	training time: 23.8044
# valid auc: 0.9315
# node dim: 10,	num_walks: 20,	walk_length: 10,	p: 0.50,	q: 0.25
# building a node2vec model...	number of walks: 166680	average walk length: 9.9884	training time: 23.9494
# valid auc: 0.9296
# node dim: 10,	num_walks: 20,	walk_length: 10,	p: 0.50,	q: 0.50
# building a node2vec model...	number of walks: 166680	average walk length: 9.9905	training time: 23.9109
# valid auc: 0.9304
# node dim: 10,	num_walks: 20,	walk_length: 10,	p: 0.50,	q: 1.25
# building a node2vec model...	number of walks: 166680	average walk length: 9.9905	training time: 23.8532
# valid auc: 0.9299
# node dim: 10,	num_walks: 20,	walk_length: 10,	p: 1.25,	q: 0.25
# building a node2vec model...	number of walks: 166680	average walk length: 9.9828	training time: 24.2257
# valid auc: 0.9292
# node dim: 10,	num_walks: 20,	walk_length: 10,	p: 1.25,	q: 0.50
# building a node2vec model...	number of walks: 166680	average walk length: 9.9881	training time: 23.9704
# valid auc: 0.9299
# node dim: 10,	num_walks: 20,	walk_length: 10,	p: 1.25,	q: 1.25
# building a node2vec model...	number of walks: 166680	average walk length: 9.9905	training time: 23.6766
# valid auc: 0.9303
# node dim: 10,	num_walks: 20,	walk_length: 20,	p: 0.25,	q: 0.25
# building a node2vec model...	number of walks: 166680	average walk length: 19.9618	training time: 32.3816
# valid auc: 0.9299
# node dim: 10,	num_walks: 20,	walk_length: 20,	p: 0.25,	q: 0.50
# building a node2vec model...	number of walks: 166680	average walk length: 19.9658	training time: 32.5429
# valid auc: 0.9292
# node dim: 10,	num_walks: 20,	walk_length: 20,	p: 0.25,	q: 1.25
# building a node2vec model...	number of walks: 166680	average walk length: 19.9712	training time: 32.2327
# valid auc: 0.9294
# node dim: 10,	num_walks: 20,	walk_length: 20,	p: 0.50,	q: 0.25
# building a node2vec model...	number of walks: 166680	average walk length: 19.9493	training time: 32.8091
# valid auc: 0.9297
# node dim: 10,	num_walks: 20,	walk_length: 20,	p: 0.50,	q: 0.50
# building a node2vec model...	number of walks: 166680	average walk length: 19.9612	training time: 32.4493
# valid auc: 0.9301
# node dim: 10,	num_walks: 20,	walk_length: 20,	p: 0.50,	q: 1.25
# building a node2vec model...	number of walks: 166680	average walk length: 19.9678	training time: 32.4228
# valid auc: 0.9305
# node dim: 10,	num_walks: 20,	walk_length: 20,	p: 1.25,	q: 0.25
# building a node2vec model...	number of walks: 166680	average walk length: 19.9294	training time: 32.3890
# valid auc: 0.9294
# node dim: 10,	num_walks: 20,	walk_length: 20,	p: 1.25,	q: 0.50
# building a node2vec model...	number of walks: 166680	average walk length: 19.9484	training time: 32.7851
# valid auc: 0.9303
# node dim: 10,	num_walks: 20,	walk_length: 20,	p: 1.25,	q: 1.25
# building a node2vec model...	number of walks: 166680	average walk length: 19.9644	training time: 32.4967
# valid auc: 0.9304
# node dim: 10,	num_walks: 20,	walk_length: 50,	p: 0.25,	q: 0.25
# building a node2vec model...	number of walks: 166680	average walk length: 49.7554	training time: 58.7551
# valid auc: 0.9235
# node dim: 10,	num_walks: 20,	walk_length: 50,	p: 0.25,	q: 0.50
# building a node2vec model...	number of walks: 166680	average walk length: 49.8110	training time: 58.5981
# valid auc: 0.9252
# node dim: 10,	num_walks: 20,	walk_length: 50,	p: 0.25,	q: 1.25
# building a node2vec model...	number of walks: 166680	average walk length: 49.8502	training time: 58.3890
# valid auc: 0.9228
# node dim: 10,	num_walks: 20,	walk_length: 50,	p: 0.50,	q: 0.25
# building a node2vec model...	number of walks: 166680	average walk length: 49.7126	training time: 58.5889
# valid auc: 0.9243
# node dim: 10,	num_walks: 20,	walk_length: 50,	p: 0.50,	q: 0.50
# building a node2vec model...	number of walks: 166680	average walk length: 49.7531	training time: 58.7623
# valid auc: 0.9244
# node dim: 10,	num_walks: 20,	walk_length: 50,	p: 0.50,	q: 1.25
# building a node2vec model...	number of walks: 166680	average walk length: 49.8300	training time: 58.5819
# valid auc: 0.9236
# node dim: 10,	num_walks: 20,	walk_length: 50,	p: 1.25,	q: 0.25
# building a node2vec model...	number of walks: 166680	average walk length: 49.6398	training time: 58.9700
# valid auc: 0.9252
# node dim: 10,	num_walks: 20,	walk_length: 50,	p: 1.25,	q: 0.50
# building a node2vec model...	number of walks: 166680	average walk length: 49.6941	training time: 59.2780
# valid auc: 0.9242
# node dim: 10,	num_walks: 20,	walk_length: 50,	p: 1.25,	q: 1.25
# building a node2vec model...	number of walks: 166680	average walk length: 49.7712	training time: 58.7284
# valid auc: 0.9244
# node dim: 10,	num_walks: 50,	walk_length: 10,	p: 0.25,	q: 0.25
# building a node2vec model...	number of walks: 416700	average walk length: 9.9906	training time: 58.7311
# valid auc: 0.9287
# node dim: 10,	num_walks: 50,	walk_length: 10,	p: 0.25,	q: 0.50
# building a node2vec model...	number of walks: 416700	average walk length: 9.9912	training time: 58.6612
# valid auc: 0.9295
# node dim: 10,	num_walks: 50,	walk_length: 10,	p: 0.25,	q: 1.25
# building a node2vec model...	number of walks: 416700	average walk length: 9.9919	training time: 58.5692
# valid auc: 0.9293
# node dim: 10,	num_walks: 50,	walk_length: 10,	p: 0.50,	q: 0.25
# building a node2vec model...	number of walks: 416700	average walk length: 9.9886	training time: 59.1576
# valid auc: 0.9289
# node dim: 10,	num_walks: 50,	walk_length: 10,	p: 0.50,	q: 0.50
# building a node2vec model...	number of walks: 416700	average walk length: 9.9905	training time: 58.6755
# valid auc: 0.9280
# node dim: 10,	num_walks: 50,	walk_length: 10,	p: 0.50,	q: 1.25
# building a node2vec model...	number of walks: 416700	average walk length: 9.9908	training time: 58.5884
# valid auc: 0.9284
# node dim: 10,	num_walks: 50,	walk_length: 10,	p: 1.25,	q: 0.25
# building a node2vec model...	number of walks: 416700	average walk length: 9.9828	training time: 58.7185
# valid auc: 0.9286
# node dim: 10,	num_walks: 50,	walk_length: 10,	p: 1.25,	q: 0.50
# building a node2vec model...	number of walks: 416700	average walk length: 9.9878	training time: 59.2735
# valid auc: 0.9284
# node dim: 10,	num_walks: 50,	walk_length: 10,	p: 1.25,	q: 1.25
# building a node2vec model...	number of walks: 416700	average walk length: 9.9906	training time: 58.8743
# valid auc: 0.9292
# node dim: 10,	num_walks: 50,	walk_length: 20,	p: 0.25,	q: 0.25
# building a node2vec model...	number of walks: 416700	average walk length: 19.9620	training time: 79.9659
# valid auc: 0.9262
# node dim: 10,	num_walks: 50,	walk_length: 20,	p: 0.25,	q: 0.50
# building a node2vec model...	number of walks: 416700	average walk length: 19.9657	training time: 80.1174
# valid auc: 0.9260
# node dim: 10,	num_walks: 50,	walk_length: 20,	p: 0.25,	q: 1.25
# building a node2vec model...	number of walks: 416700	average walk length: 19.9697	training time: 79.7214
# valid auc: 0.9251
# node dim: 10,	num_walks: 50,	walk_length: 20,	p: 0.50,	q: 0.25
# building a node2vec model...	number of walks: 416700	average walk length: 19.9492	training time: 80.2785
# valid auc: 0.9268
# node dim: 10,	num_walks: 50,	walk_length: 20,	p: 0.50,	q: 0.50
# building a node2vec model...	number of walks: 416700	average walk length: 19.9621	training time: 80.0275
# valid auc: 0.9264
# node dim: 10,	num_walks: 50,	walk_length: 20,	p: 0.50,	q: 1.25
# building a node2vec model...	number of walks: 416700	average walk length: 19.9687	training time: 80.0270
# valid auc: 0.9253
# node dim: 10,	num_walks: 50,	walk_length: 20,	p: 1.25,	q: 0.25
# building a node2vec model...	number of walks: 416700	average walk length: 19.9289	training time: 80.6066
# valid auc: 0.9258
# node dim: 10,	num_walks: 50,	walk_length: 20,	p: 1.25,	q: 0.50
# building a node2vec model...	number of walks: 416700	average walk length: 19.9476	training time: 80.4975
# valid auc: 0.9268
# node dim: 10,	num_walks: 50,	walk_length: 20,	p: 1.25,	q: 1.25
# building a node2vec model...	number of walks: 416700	average walk length: 19.9639	training time: 80.2282
# valid auc: 0.9258
# node dim: 10,	num_walks: 50,	walk_length: 50,	p: 0.25,	q: 0.25
# building a node2vec model...	number of walks: 416700	average walk length: 49.7587	training time: 145.8453
# valid auc: 0.9208
# node dim: 10,	num_walks: 50,	walk_length: 50,	p: 0.25,	q: 0.50
# building a node2vec model...	number of walks: 416700	average walk length: 49.8101	training time: 146.0201
# valid auc: 0.9205
# node dim: 10,	num_walks: 50,	walk_length: 50,	p: 0.25,	q: 1.25
# building a node2vec model...	number of walks: 416700	average walk length: 49.8544	training time: 144.5528
# valid auc: 0.9204
# node dim: 10,	num_walks: 50,	walk_length: 50,	p: 0.50,	q: 0.25
# building a node2vec model...	number of walks: 416700	average walk length: 49.7110	training time: 146.1870
# valid auc: 0.9220
# node dim: 10,	num_walks: 50,	walk_length: 50,	p: 0.50,	q: 0.50
# building a node2vec model...	number of walks: 416700	average walk length: 49.7619	training time: 145.9085
# valid auc: 0.9224
# node dim: 10,	num_walks: 50,	walk_length: 50,	p: 0.50,	q: 1.25
# building a node2vec model...	number of walks: 416700	average walk length: 49.8290	training time: 145.1378
# valid auc: 0.9208
# node dim: 10,	num_walks: 50,	walk_length: 50,	p: 1.25,	q: 0.25
# building a node2vec model...	number of walks: 416700	average walk length: 49.6359	training time: 145.9805
# valid auc: 0.9228
# node dim: 10,	num_walks: 50,	walk_length: 50,	p: 1.25,	q: 0.50
# building a node2vec model...	number of walks: 416700	average walk length: 49.6977	training time: 146.3583
# valid auc: 0.9226
# node dim: 10,	num_walks: 50,	walk_length: 50,	p: 1.25,	q: 1.25
# building a node2vec model...	number of walks: 416700	average walk length: 49.7730	training time: 145.6687
# valid auc: 0.9218
# node dim: 20,	num_walks: 10,	walk_length: 10,	p: 0.25,	q: 0.25
# building a node2vec model...	number of walks: 83340	average walk length: 9.9913	training time: 12.2527
# valid auc: 0.9119
# node dim: 20,	num_walks: 10,	walk_length: 10,	p: 0.25,	q: 0.50
# building a node2vec model...	number of walks: 83340	average walk length: 9.9910	training time: 12.0681
# valid auc: 0.9131
# node dim: 20,	num_walks: 10,	walk_length: 10,	p: 0.25,	q: 1.25
# building a node2vec model...	number of walks: 83340	average walk length: 9.9922	training time: 12.0733
# valid auc: 0.9157
# node dim: 20,	num_walks: 10,	walk_length: 10,	p: 0.50,	q: 0.25
# building a node2vec model...	number of walks: 83340	average walk length: 9.9883	training time: 12.1383
# valid auc: 0.9086
# node dim: 20,	num_walks: 10,	walk_length: 10,	p: 0.50,	q: 0.50
# building a node2vec model...	number of walks: 83340	average walk length: 9.9904	training time: 12.2145
# valid auc: 0.9113
# node dim: 20,	num_walks: 10,	walk_length: 10,	p: 0.50,	q: 1.25
# building a node2vec model...	number of walks: 83340	average walk length: 9.9906	training time: 12.1481
# valid auc: 0.9139
# node dim: 20,	num_walks: 10,	walk_length: 10,	p: 1.25,	q: 0.25
# building a node2vec model...	number of walks: 83340	average walk length: 9.9836	training time: 12.2112
# valid auc: 0.9056
# node dim: 20,	num_walks: 10,	walk_length: 10,	p: 1.25,	q: 0.50
# building a node2vec model...	number of walks: 83340	average walk length: 9.9875	training time: 12.3518
# valid auc: 0.9073
# node dim: 20,	num_walks: 10,	walk_length: 10,	p: 1.25,	q: 1.25
# building a node2vec model...	number of walks: 83340	average walk length: 9.9899	training time: 12.0423
# valid auc: 0.9099
# node dim: 20,	num_walks: 10,	walk_length: 20,	p: 0.25,	q: 0.25
# building a node2vec model...	number of walks: 83340	average walk length: 19.9599	training time: 16.5165
# valid auc: 0.9223
# node dim: 20,	num_walks: 10,	walk_length: 20,	p: 0.25,	q: 0.50
# building a node2vec model...	number of walks: 83340	average walk length: 19.9671	training time: 16.4295
# valid auc: 0.9230
# node dim: 20,	num_walks: 10,	walk_length: 20,	p: 0.25,	q: 1.25
# building a node2vec model...	number of walks: 83340	average walk length: 19.9704	training time: 16.4726
# valid auc: 0.9246
# node dim: 20,	num_walks: 10,	walk_length: 20,	p: 0.50,	q: 0.25
# building a node2vec model...	number of walks: 83340	average walk length: 19.9485	training time: 16.8202
# valid auc: 0.9217
# node dim: 20,	num_walks: 10,	walk_length: 20,	p: 0.50,	q: 0.50
# building a node2vec model...	number of walks: 83340	average walk length: 19.9600	training time: 16.5758
# valid auc: 0.9228
# node dim: 20,	num_walks: 10,	walk_length: 20,	p: 0.50,	q: 1.25
# building a node2vec model...	number of walks: 83340	average walk length: 19.9677	training time: 16.3961
# valid auc: 0.9214
# node dim: 20,	num_walks: 10,	walk_length: 20,	p: 1.25,	q: 0.25
# building a node2vec model...	number of walks: 83340	average walk length: 19.9289	training time: 16.5844
# valid auc: 0.9220
# node dim: 20,	num_walks: 10,	walk_length: 20,	p: 1.25,	q: 0.50
# building a node2vec model...	number of walks: 83340	average walk length: 19.9497	training time: 16.7064
# valid auc: 0.9218
# node dim: 20,	num_walks: 10,	walk_length: 20,	p: 1.25,	q: 1.25
# building a node2vec model...	number of walks: 83340	average walk length: 19.9636	training time: 16.6614
# valid auc: 0.9227
# node dim: 20,	num_walks: 10,	walk_length: 50,	p: 0.25,	q: 0.25
# building a node2vec model...	number of walks: 83340	average walk length: 49.7593	training time: 29.6374
# valid auc: 0.9193
# node dim: 20,	num_walks: 10,	walk_length: 50,	p: 0.25,	q: 0.50
# building a node2vec model...	number of walks: 83340	average walk length: 49.8189	training time: 29.7867
# valid auc: 0.9196
# node dim: 20,	num_walks: 10,	walk_length: 50,	p: 0.25,	q: 1.25
# building a node2vec model...	number of walks: 83340	average walk length: 49.8485	training time: 29.5384
# valid auc: 0.9189
# node dim: 20,	num_walks: 10,	walk_length: 50,	p: 0.50,	q: 0.25
# building a node2vec model...	number of walks: 83340	average walk length: 49.7103	training time: 29.7375
# valid auc: 0.9194
# node dim: 20,	num_walks: 10,	walk_length: 50,	p: 0.50,	q: 0.50
# building a node2vec model...	number of walks: 83340	average walk length: 49.7449	training time: 29.6854
# valid auc: 0.9199
# node dim: 20,	num_walks: 10,	walk_length: 50,	p: 0.50,	q: 1.25
# building a node2vec model...	number of walks: 83340	average walk length: 49.8280	training time: 29.5581
# valid auc: 0.9194
# node dim: 20,	num_walks: 10,	walk_length: 50,	p: 1.25,	q: 0.25
# building a node2vec model...	number of walks: 83340	average walk length: 49.6407	training time: 29.8861
# valid auc: 0.9201
# node dim: 20,	num_walks: 10,	walk_length: 50,	p: 1.25,	q: 0.50
# building a node2vec model...	number of walks: 83340	average walk length: 49.6884	training time: 29.7512
# valid auc: 0.9214
# node dim: 20,	num_walks: 10,	walk_length: 50,	p: 1.25,	q: 1.25
# building a node2vec model...	number of walks: 83340	average walk length: 49.7727	training time: 29.8232
# valid auc: 0.9210
# node dim: 20,	num_walks: 20,	walk_length: 10,	p: 0.25,	q: 0.25
# building a node2vec model...	number of walks: 166680	average walk length: 9.9911	training time: 23.8908
# valid auc: 0.9231
# node dim: 20,	num_walks: 20,	walk_length: 10,	p: 0.25,	q: 0.50
# building a node2vec model...	number of walks: 166680	average walk length: 9.9912	training time: 23.7469
# valid auc: 0.9242
# node dim: 20,	num_walks: 20,	walk_length: 10,	p: 0.25,	q: 1.25
# building a node2vec model...	number of walks: 166680	average walk length: 9.9925	training time: 23.7323
# valid auc: 0.9246
# node dim: 20,	num_walks: 20,	walk_length: 10,	p: 0.50,	q: 0.25
# building a node2vec model...	number of walks: 166680	average walk length: 9.9884	training time: 23.9027
# valid auc: 0.9222
# node dim: 20,	num_walks: 20,	walk_length: 10,	p: 0.50,	q: 0.50
# building a node2vec model...	number of walks: 166680	average walk length: 9.9905	training time: 24.0364
# valid auc: 0.9218
# node dim: 20,	num_walks: 20,	walk_length: 10,	p: 0.50,	q: 1.25
# building a node2vec model...	number of walks: 166680	average walk length: 9.9905	training time: 23.7833
# valid auc: 0.9218
# node dim: 20,	num_walks: 20,	walk_length: 10,	p: 1.25,	q: 0.25
# building a node2vec model...	number of walks: 166680	average walk length: 9.9828	training time: 23.8482
# valid auc: 0.9218
# node dim: 20,	num_walks: 20,	walk_length: 10,	p: 1.25,	q: 0.50
# building a node2vec model...	number of walks: 166680	average walk length: 9.9881	training time: 23.9170
# valid auc: 0.9216
# node dim: 20,	num_walks: 20,	walk_length: 10,	p: 1.25,	q: 1.25
# building a node2vec model...	number of walks: 166680	average walk length: 9.9905	training time: 23.7316
# valid auc: 0.9219
# node dim: 20,	num_walks: 20,	walk_length: 20,	p: 0.25,	q: 0.25
# building a node2vec model...	number of walks: 166680	average walk length: 19.9618	training time: 32.4214
# valid auc: 0.9229
# node dim: 20,	num_walks: 20,	walk_length: 20,	p: 0.25,	q: 0.50
# building a node2vec model...	number of walks: 166680	average walk length: 19.9658	training time: 32.2340
# valid auc: 0.9239
# node dim: 20,	num_walks: 20,	walk_length: 20,	p: 0.25,	q: 1.25
# building a node2vec model...	number of walks: 166680	average walk length: 19.9712	training time: 32.3138
# valid auc: 0.9225
# node dim: 20,	num_walks: 20,	walk_length: 20,	p: 0.50,	q: 0.25
# building a node2vec model...	number of walks: 166680	average walk length: 19.9493	training time: 32.5083
# valid auc: 0.9230
# node dim: 20,	num_walks: 20,	walk_length: 20,	p: 0.50,	q: 0.50
# building a node2vec model...	number of walks: 166680	average walk length: 19.9612	training time: 32.5271
# valid auc: 0.9247
# node dim: 20,	num_walks: 20,	walk_length: 20,	p: 0.50,	q: 1.25
# building a node2vec model...	number of walks: 166680	average walk length: 19.9678	training time: 32.3252
# valid auc: 0.9228
# node dim: 20,	num_walks: 20,	walk_length: 20,	p: 1.25,	q: 0.25
# building a node2vec model...	number of walks: 166680	average walk length: 19.9294	training time: 32.6160
# valid auc: 0.9234
# node dim: 20,	num_walks: 20,	walk_length: 20,	p: 1.25,	q: 0.50
# building a node2vec model...	number of walks: 166680	average walk length: 19.9484	training time: 32.4363
# valid auc: 0.9237
# node dim: 20,	num_walks: 20,	walk_length: 20,	p: 1.25,	q: 1.25
# building a node2vec model...	number of walks: 166680	average walk length: 19.9644	training time: 32.5563
# valid auc: 0.9239
# node dim: 20,	num_walks: 20,	walk_length: 50,	p: 0.25,	q: 0.25
# building a node2vec model...	number of walks: 166680	average walk length: 49.7554	training time: 59.0020
# valid auc: 0.9172
# node dim: 20,	num_walks: 20,	walk_length: 50,	p: 0.25,	q: 0.50
# building a node2vec model...	number of walks: 166680	average walk length: 49.8110	training time: 58.4758
# valid auc: 0.9171
# node dim: 20,	num_walks: 20,	walk_length: 50,	p: 0.25,	q: 1.25
# building a node2vec model...	number of walks: 166680	average walk length: 49.8502	training time: 58.2545
# valid auc: 0.9148
# node dim: 20,	num_walks: 20,	walk_length: 50,	p: 0.50,	q: 0.25
# building a node2vec model...	number of walks: 166680	average walk length: 49.7126	training time: 59.0434
# valid auc: 0.9176
# node dim: 20,	num_walks: 20,	walk_length: 50,	p: 0.50,	q: 0.50
# building a node2vec model...	number of walks: 166680	average walk length: 49.7531	training time: 58.7993
# valid auc: 0.9172
# node dim: 20,	num_walks: 20,	walk_length: 50,	p: 0.50,	q: 1.25
# building a node2vec model...	number of walks: 166680	average walk length: 49.8300	training time: 58.6961
# valid auc: 0.9158
# node dim: 20,	num_walks: 20,	walk_length: 50,	p: 1.25,	q: 0.25
# building a node2vec model...	number of walks: 166680	average walk length: 49.6398	training time: 58.9212
# valid auc: 0.9174
# node dim: 20,	num_walks: 20,	walk_length: 50,	p: 1.25,	q: 0.50
# building a node2vec model...	number of walks: 166680	average walk length: 49.6941	training time: 59.0950
# valid auc: 0.9180
# node dim: 20,	num_walks: 20,	walk_length: 50,	p: 1.25,	q: 1.25
# building a node2vec model...	number of walks: 166680	average walk length: 49.7712	training time: 58.8556
# valid auc: 0.9167
# node dim: 20,	num_walks: 50,	walk_length: 10,	p: 0.25,	q: 0.25
# building a node2vec model...	number of walks: 416700	average walk length: 9.9906	training time: 58.8932
# valid auc: 0.9244
# node dim: 20,	num_walks: 50,	walk_length: 10,	p: 0.25,	q: 0.50
# building a node2vec model...	number of walks: 416700	average walk length: 9.9912	training time: 58.5835
# valid auc: 0.9253
# node dim: 20,	num_walks: 50,	walk_length: 10,	p: 0.25,	q: 1.25
# building a node2vec model...	number of walks: 416700	average walk length: 9.9919	training time: 58.4538
# valid auc: 0.9249
# node dim: 20,	num_walks: 50,	walk_length: 10,	p: 0.50,	q: 0.25
# building a node2vec model...	number of walks: 416700	average walk length: 9.9886	training time: 58.9052
# valid auc: 0.9248
# node dim: 20,	num_walks: 50,	walk_length: 10,	p: 0.50,	q: 0.50
# building a node2vec model...	number of walks: 416700	average walk length: 9.9905	training time: 58.8093
# valid auc: 0.9257
# node dim: 20,	num_walks: 50,	walk_length: 10,	p: 0.50,	q: 1.25
# building a node2vec model...	number of walks: 416700	average walk length: 9.9908	training time: 58.8917
# valid auc: 0.9248
# node dim: 20,	num_walks: 50,	walk_length: 10,	p: 1.25,	q: 0.25
# building a node2vec model...	number of walks: 416700	average walk length: 9.9828	training time: 58.7513
# valid auc: 0.9241
# node dim: 20,	num_walks: 50,	walk_length: 10,	p: 1.25,	q: 0.50
# building a node2vec model...	number of walks: 416700	average walk length: 9.9878	training time: 58.9721
# valid auc: 0.9243
# node dim: 20,	num_walks: 50,	walk_length: 10,	p: 1.25,	q: 1.25
# building a node2vec model...	number of walks: 416700	average walk length: 9.9906	training time: 58.9957
# valid auc: 0.9258
# node dim: 20,	num_walks: 50,	walk_length: 20,	p: 0.25,	q: 0.25
# building a node2vec model...	number of walks: 416700	average walk length: 19.9620	training time: 80.3946
# valid auc: 0.9208
# node dim: 20,	num_walks: 50,	walk_length: 20,	p: 0.25,	q: 0.50
# building a node2vec model...	number of walks: 416700	average walk length: 19.9657	training time: 79.9525
# valid auc: 0.9210
# node dim: 20,	num_walks: 50,	walk_length: 20,	p: 0.25,	q: 1.25
# building a node2vec model...	number of walks: 416700	average walk length: 19.9697	training time: 79.7797
# valid auc: 0.9201
# node dim: 20,	num_walks: 50,	walk_length: 20,	p: 0.50,	q: 0.25
# building a node2vec model...	number of walks: 416700	average walk length: 19.9492	training time: 79.9808
# valid auc: 0.9206
# node dim: 20,	num_walks: 50,	walk_length: 20,	p: 0.50,	q: 0.50
# building a node2vec model...	number of walks: 416700	average walk length: 19.9621	training time: 80.4371
# valid auc: 0.9212
# node dim: 20,	num_walks: 50,	walk_length: 20,	p: 0.50,	q: 1.25
# building a node2vec model...	number of walks: 416700	average walk length: 19.9687	training time: 80.2206
# valid auc: 0.9210
# node dim: 20,	num_walks: 50,	walk_length: 20,	p: 1.25,	q: 0.25
# building a node2vec model...	number of walks: 416700	average walk length: 19.9289	training time: 80.3602
# valid auc: 0.9220
# node dim: 20,	num_walks: 50,	walk_length: 20,	p: 1.25,	q: 0.50
# building a node2vec model...	number of walks: 416700	average walk length: 19.9476	training time: 80.3497
# valid auc: 0.9220
# node dim: 20,	num_walks: 50,	walk_length: 20,	p: 1.25,	q: 1.25
# building a node2vec model...	number of walks: 416700	average walk length: 19.9639	training time: 80.2325
# valid auc: 0.9210
# node dim: 20,	num_walks: 50,	walk_length: 50,	p: 0.25,	q: 0.25
# building a node2vec model...	number of walks: 416700	average walk length: 49.7587	training time: 145.9207
# valid auc: 0.9144
# node dim: 20,	num_walks: 50,	walk_length: 50,	p: 0.25,	q: 0.50
# building a node2vec model...	number of walks: 416700	average walk length: 49.8101	training time: 146.0385
# valid auc: 0.9135
# node dim: 20,	num_walks: 50,	walk_length: 50,	p: 0.25,	q: 1.25
# building a node2vec model...	number of walks: 416700	average walk length: 49.8544	training time: 144.9216
# valid auc: 0.9118
# node dim: 20,	num_walks: 50,	walk_length: 50,	p: 0.50,	q: 0.25
# building a node2vec model...	number of walks: 416700	average walk length: 49.7110	training time: 146.6819
# valid auc: 0.9160
# node dim: 20,	num_walks: 50,	walk_length: 50,	p: 0.50,	q: 0.50
# building a node2vec model...	number of walks: 416700	average walk length: 49.7619	training time: 146.1783
# valid auc: 0.9156
# node dim: 20,	num_walks: 50,	walk_length: 50,	p: 0.50,	q: 1.25
# building a node2vec model...	number of walks: 416700	average walk length: 49.8290	training time: 145.8936
# valid auc: 0.9138
# node dim: 20,	num_walks: 50,	walk_length: 50,	p: 1.25,	q: 0.25
# building a node2vec model...	number of walks: 416700	average walk length: 49.6359	training time: 147.4661
# valid auc: 0.9159
# node dim: 20,	num_walks: 50,	walk_length: 50,	p: 1.25,	q: 0.50
# building a node2vec model...	number of walks: 416700	average walk length: 49.6977	training time: 146.4350
# valid auc: 0.9155
# node dim: 20,	num_walks: 50,	walk_length: 50,	p: 1.25,	q: 1.25
# building a node2vec model...	number of walks: 416700	average walk length: 49.7730	training time: 145.8787
# valid auc: 0.9154
# node dim: 50,	num_walks: 10,	walk_length: 10,	p: 0.25,	q: 0.25
# building a node2vec model...	number of walks: 83340	average walk length: 9.9913	training time: 12.4530
# valid auc: 0.8359
# node dim: 50,	num_walks: 10,	walk_length: 10,	p: 0.25,	q: 0.50
# building a node2vec model...	number of walks: 83340	average walk length: 9.9910	training time: 12.4531
# valid auc: 0.8386
# node dim: 50,	num_walks: 10,	walk_length: 10,	p: 0.25,	q: 1.25
# building a node2vec model...	number of walks: 83340	average walk length: 9.9922	training time: 12.4326
# valid auc: 0.8412
# node dim: 50,	num_walks: 10,	walk_length: 10,	p: 0.50,	q: 0.25
# building a node2vec model...	number of walks: 83340	average walk length: 9.9883	training time: 12.5264
# valid auc: 0.8303
# node dim: 50,	num_walks: 10,	walk_length: 10,	p: 0.50,	q: 0.50
# building a node2vec model...	number of walks: 83340	average walk length: 9.9904	training time: 12.5093
# valid auc: 0.8335
# node dim: 50,	num_walks: 10,	walk_length: 10,	p: 0.50,	q: 1.25
# building a node2vec model...	number of walks: 83340	average walk length: 9.9906	training time: 12.4195
# valid auc: 0.8367
# node dim: 50,	num_walks: 10,	walk_length: 10,	p: 1.25,	q: 0.25
# building a node2vec model...	number of walks: 83340	average walk length: 9.9836	training time: 12.5519
# valid auc: 0.8262
# node dim: 50,	num_walks: 10,	walk_length: 10,	p: 1.25,	q: 0.50
# building a node2vec model...	number of walks: 83340	average walk length: 9.9875	training time: 12.6134
# valid auc: 0.8265
# node dim: 50,	num_walks: 10,	walk_length: 10,	p: 1.25,	q: 1.25
# building a node2vec model...	number of walks: 83340	average walk length: 9.9899	training time: 12.5671
# valid auc: 0.8296
# node dim: 50,	num_walks: 10,	walk_length: 20,	p: 0.25,	q: 0.25
# building a node2vec model...	number of walks: 83340	average walk length: 19.9599	training time: 17.2407
# valid auc: 0.8709
# node dim: 50,	num_walks: 10,	walk_length: 20,	p: 0.25,	q: 0.50
# building a node2vec model...	number of walks: 83340	average walk length: 19.9671	training time: 17.2079
# valid auc: 0.8706
# node dim: 50,	num_walks: 10,	walk_length: 20,	p: 0.25,	q: 1.25
# building a node2vec model...	number of walks: 83340	average walk length: 19.9704	training time: 17.1434
# valid auc: 0.8699
# node dim: 50,	num_walks: 10,	walk_length: 20,	p: 0.50,	q: 0.25
# building a node2vec model...	number of walks: 83340	average walk length: 19.9485	training time: 17.3169
# valid auc: 0.8683
# node dim: 50,	num_walks: 10,	walk_length: 20,	p: 0.50,	q: 0.50
# building a node2vec model...	number of walks: 83340	average walk length: 19.9600	training time: 17.2482
# valid auc: 0.8703
# node dim: 50,	num_walks: 10,	walk_length: 20,	p: 0.50,	q: 1.25
# building a node2vec model...	number of walks: 83340	average walk length: 19.9677	training time: 17.1812
# valid auc: 0.8679
# node dim: 50,	num_walks: 10,	walk_length: 20,	p: 1.25,	q: 0.25
# building a node2vec model...	number of walks: 83340	average walk length: 19.9289	training time: 17.1476
# valid auc: 0.8681
# node dim: 50,	num_walks: 10,	walk_length: 20,	p: 1.25,	q: 0.50
# building a node2vec model...	number of walks: 83340	average walk length: 19.9497	training time: 17.3557
# valid auc: 0.8690
# node dim: 50,	num_walks: 10,	walk_length: 20,	p: 1.25,	q: 1.25
# building a node2vec model...	number of walks: 83340	average walk length: 19.9636	training time: 17.3138
# valid auc: 0.8672
# node dim: 50,	num_walks: 10,	walk_length: 50,	p: 0.25,	q: 0.25
# building a node2vec model...	number of walks: 83340	average walk length: 49.7593	training time: 31.9195
# valid auc: 0.8781
# node dim: 50,	num_walks: 10,	walk_length: 50,	p: 0.25,	q: 0.50
# building a node2vec model...	number of walks: 83340	average walk length: 49.8189	training time: 31.7450
# valid auc: 0.8758
# node dim: 50,	num_walks: 10,	walk_length: 50,	p: 0.25,	q: 1.25
# building a node2vec model...	number of walks: 83340	average walk length: 49.8485	training time: 31.5668
# valid auc: 0.8706
# node dim: 50,	num_walks: 10,	walk_length: 50,	p: 0.50,	q: 0.25
# building a node2vec model...	number of walks: 83340	average walk length: 49.7103	training time: 31.9333
# valid auc: 0.8772
# node dim: 50,	num_walks: 10,	walk_length: 50,	p: 0.50,	q: 0.50
# building a node2vec model...	number of walks: 83340	average walk length: 49.7449	training time: 31.7769
# valid auc: 0.8754
# node dim: 50,	num_walks: 10,	walk_length: 50,	p: 0.50,	q: 1.25
# building a node2vec model...	number of walks: 83340	average walk length: 49.8280	training time: 31.5965
# valid auc: 0.8716
# node dim: 50,	num_walks: 10,	walk_length: 50,	p: 1.25,	q: 0.25
# building a node2vec model...	number of walks: 83340	average walk length: 49.6407	training time: 32.0117
# valid auc: 0.8782
# node dim: 50,	num_walks: 10,	walk_length: 50,	p: 1.25,	q: 0.50
# building a node2vec model...	number of walks: 83340	average walk length: 49.6884	training time: 31.8407
# valid auc: 0.8765
# node dim: 50,	num_walks: 10,	walk_length: 50,	p: 1.25,	q: 1.25
# building a node2vec model...	number of walks: 83340	average walk length: 49.7727	training time: 31.8044
# valid auc: 0.8741
# node dim: 50,	num_walks: 20,	walk_length: 10,	p: 0.25,	q: 0.25
# building a node2vec model...	number of walks: 166680	average walk length: 9.9911	training time: 24.4481
# valid auc: 0.8724
# node dim: 50,	num_walks: 20,	walk_length: 10,	p: 0.25,	q: 0.50
# building a node2vec model...	number of walks: 166680	average walk length: 9.9912	training time: 24.2872
# valid auc: 0.8726
# node dim: 50,	num_walks: 20,	walk_length: 10,	p: 0.25,	q: 1.25
# building a node2vec model...	number of walks: 166680	average walk length: 9.9925	training time: 24.1877
# valid auc: 0.8705
# node dim: 50,	num_walks: 20,	walk_length: 10,	p: 0.50,	q: 0.25
# building a node2vec model...	number of walks: 166680	average walk length: 9.9884	training time: 24.5066
# valid auc: 0.8700
# node dim: 50,	num_walks: 20,	walk_length: 10,	p: 0.50,	q: 0.50
# building a node2vec model...	number of walks: 166680	average walk length: 9.9905	training time: 24.4078
# valid auc: 0.8711
# node dim: 50,	num_walks: 20,	walk_length: 10,	p: 0.50,	q: 1.25
# building a node2vec model...	number of walks: 166680	average walk length: 9.9905	training time: 24.2380
# valid auc: 0.8675
# node dim: 50,	num_walks: 20,	walk_length: 10,	p: 1.25,	q: 0.25
# building a node2vec model...	number of walks: 166680	average walk length: 9.9828	training time: 24.3228
# valid auc: 0.8681
# node dim: 50,	num_walks: 20,	walk_length: 10,	p: 1.25,	q: 0.50
# building a node2vec model...	number of walks: 166680	average walk length: 9.9881	training time: 24.4279
# valid auc: 0.8683
# node dim: 50,	num_walks: 20,	walk_length: 10,	p: 1.25,	q: 1.25
# building a node2vec model...	number of walks: 166680	average walk length: 9.9905	training time: 24.4517
# valid auc: 0.8670
# node dim: 50,	num_walks: 20,	walk_length: 20,	p: 0.25,	q: 0.25
# building a node2vec model...	number of walks: 166680	average walk length: 19.9618	training time: 33.7099
# valid auc: 0.8849
# node dim: 50,	num_walks: 20,	walk_length: 20,	p: 0.25,	q: 0.50
# building a node2vec model...	number of walks: 166680	average walk length: 19.9658	training time: 33.8115
# valid auc: 0.8853
# node dim: 50,	num_walks: 20,	walk_length: 20,	p: 0.25,	q: 1.25
# building a node2vec model...	number of walks: 166680	average walk length: 19.9712	training time: 33.4978
# valid auc: 0.8801
# node dim: 50,	num_walks: 20,	walk_length: 20,	p: 0.50,	q: 0.25
# building a node2vec model...	number of walks: 166680	average walk length: 19.9493	training time: 33.8249
# valid auc: 0.8854
# node dim: 50,	num_walks: 20,	walk_length: 20,	p: 0.50,	q: 0.50
# building a node2vec model...	number of walks: 166680	average walk length: 19.9612	training time: 34.0375
# valid auc: 0.8844
# node dim: 50,	num_walks: 20,	walk_length: 20,	p: 0.50,	q: 1.25
# building a node2vec model...	number of walks: 166680	average walk length: 19.9678	training time: 33.6889
# valid auc: 0.8805
# node dim: 50,	num_walks: 20,	walk_length: 20,	p: 1.25,	q: 0.25
# building a node2vec model...	number of walks: 166680	average walk length: 19.9294	training time: 33.9258
# valid auc: 0.8844
# node dim: 50,	num_walks: 20,	walk_length: 20,	p: 1.25,	q: 0.50
# building a node2vec model...	number of walks: 166680	average walk length: 19.9484	training time: 33.7667
# valid auc: 0.8840
# node dim: 50,	num_walks: 20,	walk_length: 20,	p: 1.25,	q: 1.25
# building a node2vec model...	number of walks: 166680	average walk length: 19.9644	training time: 33.7815
# valid auc: 0.8807
# node dim: 50,	num_walks: 20,	walk_length: 50,	p: 0.25,	q: 0.25
# building a node2vec model...	number of walks: 166680	average walk length: 49.7554	training time: 62.9167
# valid auc: 0.8782
# node dim: 50,	num_walks: 20,	walk_length: 50,	p: 0.25,	q: 0.50
# building a node2vec model...	number of walks: 166680	average walk length: 49.8110	training time: 63.3217
# valid auc: 0.8757
# node dim: 50,	num_walks: 20,	walk_length: 50,	p: 0.25,	q: 1.25
# building a node2vec model...	number of walks: 166680	average walk length: 49.8502	training time: 62.1365
# valid auc: 0.8673
# node dim: 50,	num_walks: 20,	walk_length: 50,	p: 0.50,	q: 0.25
# building a node2vec model...	number of walks: 166680	average walk length: 49.7126	training time: 63.0633
# valid auc: 0.8809
# node dim: 50,	num_walks: 20,	walk_length: 50,	p: 0.50,	q: 0.50
# building a node2vec model...	number of walks: 166680	average walk length: 49.7531	training time: 62.6837
# valid auc: 0.8784
# node dim: 50,	num_walks: 20,	walk_length: 50,	p: 0.50,	q: 1.25
# building a node2vec model...	number of walks: 166680	average walk length: 49.8300	training time: 62.6476
# valid auc: 0.8717
# node dim: 50,	num_walks: 20,	walk_length: 50,	p: 1.25,	q: 0.25
# building a node2vec model...	number of walks: 166680	average walk length: 49.6398	training time: 63.0864
# valid auc: 0.8817
# node dim: 50,	num_walks: 20,	walk_length: 50,	p: 1.25,	q: 0.50
# building a node2vec model...	number of walks: 166680	average walk length: 49.6941	training time: 62.9529
# valid auc: 0.8804
# node dim: 50,	num_walks: 20,	walk_length: 50,	p: 1.25,	q: 1.25
# building a node2vec model...	number of walks: 166680	average walk length: 49.7712	training time: 62.9031
# valid auc: 0.8761
# node dim: 50,	num_walks: 50,	walk_length: 10,	p: 0.25,	q: 0.25
# building a node2vec model...	number of walks: 416700	average walk length: 9.9906	training time: 59.8944
# valid auc: 0.8898
# node dim: 50,	num_walks: 50,	walk_length: 10,	p: 0.25,	q: 0.50
# building a node2vec model...	number of walks: 416700	average walk length: 9.9912	training time: 59.4342
# valid auc: 0.8907
# node dim: 50,	num_walks: 50,	walk_length: 10,	p: 0.25,	q: 1.25
# building a node2vec model...	number of walks: 416700	average walk length: 9.9919	training time: 59.1639
# valid auc: 0.8868
# node dim: 50,	num_walks: 50,	walk_length: 10,	p: 0.50,	q: 0.25
# building a node2vec model...	number of walks: 416700	average walk length: 9.9886	training time: 59.9085
# valid auc: 0.8917
# node dim: 50,	num_walks: 50,	walk_length: 10,	p: 0.50,	q: 0.50
# building a node2vec model...	number of walks: 416700	average walk length: 9.9905	training time: 59.6946
# valid auc: 0.8904
# node dim: 50,	num_walks: 50,	walk_length: 10,	p: 0.50,	q: 1.25
# building a node2vec model...	number of walks: 416700	average walk length: 9.9908	training time: 59.4570
# valid auc: 0.8872
# node dim: 50,	num_walks: 50,	walk_length: 10,	p: 1.25,	q: 0.25
# building a node2vec model...	number of walks: 416700	average walk length: 9.9828	training time: 59.6552
# valid auc: 0.8910
# node dim: 50,	num_walks: 50,	walk_length: 10,	p: 1.25,	q: 0.50
# building a node2vec model...	number of walks: 416700	average walk length: 9.9878	training time: 59.8691
# valid auc: 0.8909
# node dim: 50,	num_walks: 50,	walk_length: 10,	p: 1.25,	q: 1.25
# building a node2vec model...	number of walks: 416700	average walk length: 9.9906	training time: 59.6940
# valid auc: 0.8879
# node dim: 50,	num_walks: 50,	walk_length: 20,	p: 0.25,	q: 0.25
# building a node2vec model...	number of walks: 416700	average walk length: 19.9620	training time: 83.1288
# valid auc: 0.8895
# node dim: 50,	num_walks: 50,	walk_length: 20,	p: 0.25,	q: 0.50
# building a node2vec model...	number of walks: 416700	average walk length: 19.9657	training time: 82.8789
# valid auc: 0.8859
# node dim: 50,	num_walks: 50,	walk_length: 20,	p: 0.25,	q: 1.25
# building a node2vec model...	number of walks: 416700	average walk length: 19.9697	training time: 82.4219
# valid auc: 0.8826
# node dim: 50,	num_walks: 50,	walk_length: 20,	p: 0.50,	q: 0.25
# building a node2vec model...	number of walks: 416700	average walk length: 19.9492	training time: 83.3141
# valid auc: 0.8888
# node dim: 50,	num_walks: 50,	walk_length: 20,	p: 0.50,	q: 0.50
# building a node2vec model...	number of walks: 416700	average walk length: 19.9621	training time: 83.2181
# valid auc: 0.8895
# node dim: 50,	num_walks: 50,	walk_length: 20,	p: 0.50,	q: 1.25
# building a node2vec model...	number of walks: 416700	average walk length: 19.9687	training time: 82.7715
# valid auc: 0.8843
# node dim: 50,	num_walks: 50,	walk_length: 20,	p: 1.25,	q: 0.25
# building a node2vec model...	number of walks: 416700	average walk length: 19.9289	training time: 83.2078
# valid auc: 0.8898
# node dim: 50,	num_walks: 50,	walk_length: 20,	p: 1.25,	q: 0.50
# building a node2vec model...	number of walks: 416700	average walk length: 19.9476	training time: 83.3735
# valid auc: 0.8910
# node dim: 50,	num_walks: 50,	walk_length: 20,	p: 1.25,	q: 1.25
# building a node2vec model...	number of walks: 416700	average walk length: 19.9639	training time: 83.2354
# valid auc: 0.8869
# node dim: 50,	num_walks: 50,	walk_length: 50,	p: 0.25,	q: 0.25
# building a node2vec model...	number of walks: 416700	average walk length: 49.7587	training time: 155.9669
# valid auc: 0.8806
# node dim: 50,	num_walks: 50,	walk_length: 50,	p: 0.25,	q: 0.50
# building a node2vec model...	number of walks: 416700	average walk length: 49.8101	training time: 156.2988
# valid auc: 0.8763
# node dim: 50,	num_walks: 50,	walk_length: 50,	p: 0.25,	q: 1.25
# building a node2vec model...	number of walks: 416700	average walk length: 49.8544	training time: 154.6178
# valid auc: 0.8687
# node dim: 50,	num_walks: 50,	walk_length: 50,	p: 0.50,	q: 0.25
# building a node2vec model...	number of walks: 416700	average walk length: 49.7110	training time: 156.9265
# valid auc: 0.8809
# node dim: 50,	num_walks: 50,	walk_length: 50,	p: 0.50,	q: 0.50
# building a node2vec model...	number of walks: 416700	average walk length: 49.7619	training time: 156.6340
# valid auc: 0.8794
# node dim: 50,	num_walks: 50,	walk_length: 50,	p: 0.50,	q: 1.25
# building a node2vec model...	number of walks: 416700	average walk length: 49.8290	training time: 155.6347
# valid auc: 0.8739
# node dim: 50,	num_walks: 50,	walk_length: 50,	p: 1.25,	q: 0.25
# building a node2vec model...	number of walks: 416700	average walk length: 49.6359	training time: 156.5143
# valid auc: 0.8829
# node dim: 50,	num_walks: 50,	walk_length: 50,	p: 1.25,	q: 0.50
# building a node2vec model...	number of walks: 416700	average walk length: 49.6977	training time: 157.7077
# valid auc: 0.8823
# node dim: 50,	num_walks: 50,	walk_length: 50,	p: 1.25,	q: 1.25
# building a node2vec model...	number of walks: 416700	average walk length: 49.7730	training time: 156.8601
# valid auc: 0.8783
# node dim: 100,	num_walks: 10,	walk_length: 10,	p: 0.25,	q: 0.25
# building a node2vec model...	number of walks: 83340	average walk length: 9.9913	training time: 12.5868
# valid auc: 0.7326
# node dim: 100,	num_walks: 10,	walk_length: 10,	p: 0.25,	q: 0.50
# building a node2vec model...	number of walks: 83340	average walk length: 9.9910	training time: 12.5024
# valid auc: 0.7359
# node dim: 100,	num_walks: 10,	walk_length: 10,	p: 0.25,	q: 1.25
# building a node2vec model...	number of walks: 83340	average walk length: 9.9922	training time: 12.3993
# valid auc: 0.7371
# node dim: 100,	num_walks: 10,	walk_length: 10,	p: 0.50,	q: 0.25
# building a node2vec model...	number of walks: 83340	average walk length: 9.9883	training time: 12.5205
# valid auc: 0.7246
# node dim: 100,	num_walks: 10,	walk_length: 10,	p: 0.50,	q: 0.50
# building a node2vec model...	number of walks: 83340	average walk length: 9.9904	training time: 12.5745
# valid auc: 0.7298
# node dim: 100,	num_walks: 10,	walk_length: 10,	p: 0.50,	q: 1.25
# building a node2vec model...	number of walks: 83340	average walk length: 9.9906	training time: 12.5990
# valid auc: 0.7326
# node dim: 100,	num_walks: 10,	walk_length: 10,	p: 1.25,	q: 0.25
# building a node2vec model...	number of walks: 83340	average walk length: 9.9836	training time: 12.6592
# valid auc: 0.7202
# node dim: 100,	num_walks: 10,	walk_length: 10,	p: 1.25,	q: 0.50
# building a node2vec model...	number of walks: 83340	average walk length: 9.9875	training time: 12.6358
# valid auc: 0.7197
# node dim: 100,	num_walks: 10,	walk_length: 10,	p: 1.25,	q: 1.25
# building a node2vec model...	number of walks: 83340	average walk length: 9.9899	training time: 12.5868
# valid auc: 0.7234
# node dim: 100,	num_walks: 10,	walk_length: 20,	p: 0.25,	q: 0.25
# building a node2vec model...	number of walks: 83340	average walk length: 19.9599	training time: 17.3177
# valid auc: 0.7849
# node dim: 100,	num_walks: 10,	walk_length: 20,	p: 0.25,	q: 0.50
# building a node2vec model...	number of walks: 83340	average walk length: 19.9671	training time: 17.5620
# valid auc: 0.7841
# node dim: 100,	num_walks: 10,	walk_length: 20,	p: 0.25,	q: 1.25
# building a node2vec model...	number of walks: 83340	average walk length: 19.9704	training time: 17.2296
# valid auc: 0.7791
# node dim: 100,	num_walks: 10,	walk_length: 20,	p: 0.50,	q: 0.25
# building a node2vec model...	number of walks: 83340	average walk length: 19.9485	training time: 17.5646
# valid auc: 0.7794
# node dim: 100,	num_walks: 10,	walk_length: 20,	p: 0.50,	q: 0.50
# building a node2vec model...	number of walks: 83340	average walk length: 19.9600	training time: 17.4480
# valid auc: 0.7805
# node dim: 100,	num_walks: 10,	walk_length: 20,	p: 0.50,	q: 1.25
# building a node2vec model...	number of walks: 83340	average walk length: 19.9677	training time: 17.3409
# valid auc: 0.7753
# node dim: 100,	num_walks: 10,	walk_length: 20,	p: 1.25,	q: 0.25
# building a node2vec model...	number of walks: 83340	average walk length: 19.9289	training time: 17.3761
# valid auc: 0.7772
# node dim: 100,	num_walks: 10,	walk_length: 20,	p: 1.25,	q: 0.50
# building a node2vec model...	number of walks: 83340	average walk length: 19.9497	training time: 17.4536
# valid auc: 0.7752
# node dim: 100,	num_walks: 10,	walk_length: 20,	p: 1.25,	q: 1.25
# building a node2vec model...	number of walks: 83340	average walk length: 19.9636	training time: 17.4215
# valid auc: 0.7713
# node dim: 100,	num_walks: 10,	walk_length: 50,	p: 0.25,	q: 0.25
# building a node2vec model...	number of walks: 83340	average walk length: 49.7593	training time: 32.1457
# valid auc: 0.8083
# node dim: 100,	num_walks: 10,	walk_length: 50,	p: 0.25,	q: 0.50
# building a node2vec model...	number of walks: 83340	average walk length: 49.8189	training time: 32.1226
# valid auc: 0.8056
# node dim: 100,	num_walks: 10,	walk_length: 50,	p: 0.25,	q: 1.25
# building a node2vec model...	number of walks: 83340	average walk length: 49.8485	training time: 31.8745
# valid auc: 0.7931
# node dim: 100,	num_walks: 10,	walk_length: 50,	p: 0.50,	q: 0.25
# building a node2vec model...	number of walks: 83340	average walk length: 49.7103	training time: 32.1264
# valid auc: 0.8111
# node dim: 100,	num_walks: 10,	walk_length: 50,	p: 0.50,	q: 0.50
# building a node2vec model...	number of walks: 83340	average walk length: 49.7449	training time: 32.0206
# valid auc: 0.8053
# node dim: 100,	num_walks: 10,	walk_length: 50,	p: 0.50,	q: 1.25
# building a node2vec model...	number of walks: 83340	average walk length: 49.8280	training time: 31.9951
# valid auc: 0.7959
# node dim: 100,	num_walks: 10,	walk_length: 50,	p: 1.25,	q: 0.25
# building a node2vec model...	number of walks: 83340	average walk length: 49.6407	training time: 32.4353
# valid auc: 0.8098
# node dim: 100,	num_walks: 10,	walk_length: 50,	p: 1.25,	q: 0.50
# building a node2vec model...	number of walks: 83340	average walk length: 49.6884	training time: 32.0211
# valid auc: 0.8065
# node dim: 100,	num_walks: 10,	walk_length: 50,	p: 1.25,	q: 1.25
# building a node2vec model...	number of walks: 83340	average walk length: 49.7727	training time: 32.2045
# valid auc: 0.7966
# node dim: 100,	num_walks: 20,	walk_length: 10,	p: 0.25,	q: 0.25
# building a node2vec model...	number of walks: 166680	average walk length: 9.9911	training time: 24.6005
# valid auc: 0.7833
# node dim: 100,	num_walks: 20,	walk_length: 10,	p: 0.25,	q: 0.50
# building a node2vec model...	number of walks: 166680	average walk length: 9.9912	training time: 24.3400
# valid auc: 0.7848
# node dim: 100,	num_walks: 20,	walk_length: 10,	p: 0.25,	q: 1.25
# building a node2vec model...	number of walks: 166680	average walk length: 9.9925	training time: 24.4132
# valid auc: 0.7802
# node dim: 100,	num_walks: 20,	walk_length: 10,	p: 0.50,	q: 0.25
# building a node2vec model...	number of walks: 166680	average walk length: 9.9884	training time: 24.4727
# valid auc: 0.7818
# node dim: 100,	num_walks: 20,	walk_length: 10,	p: 0.50,	q: 0.50
# building a node2vec model...	number of walks: 166680	average walk length: 9.9905	training time: 24.5241
# valid auc: 0.7824
# node dim: 100,	num_walks: 20,	walk_length: 10,	p: 0.50,	q: 1.25
# building a node2vec model...	number of walks: 166680	average walk length: 9.9905	training time: 24.6354
# valid auc: 0.7745
# node dim: 100,	num_walks: 20,	walk_length: 10,	p: 1.25,	q: 0.25
# building a node2vec model...	number of walks: 166680	average walk length: 9.9828	training time: 24.6258
# valid auc: 0.7758
# node dim: 100,	num_walks: 20,	walk_length: 10,	p: 1.25,	q: 0.50
# building a node2vec model...	number of walks: 166680	average walk length: 9.9881	training time: 24.5200
# valid auc: 0.7742
# node dim: 100,	num_walks: 20,	walk_length: 10,	p: 1.25,	q: 1.25
# building a node2vec model...	number of walks: 166680	average walk length: 9.9905	training time: 24.6573
# valid auc: 0.7714
# node dim: 100,	num_walks: 20,	walk_length: 20,	p: 0.25,	q: 0.25
# building a node2vec model...	number of walks: 166680	average walk length: 19.9618	training time: 34.0646
# valid auc: 0.8182
# node dim: 100,	num_walks: 20,	walk_length: 20,	p: 0.25,	q: 0.50
# building a node2vec model...	number of walks: 166680	average walk length: 19.9658	training time: 33.9194
# valid auc: 0.8144
# node dim: 100,	num_walks: 20,	walk_length: 20,	p: 0.25,	q: 1.25
# building a node2vec model...	number of walks: 166680	average walk length: 19.9712	training time: 33.8779
# valid auc: 0.8060
# node dim: 100,	num_walks: 20,	walk_length: 20,	p: 0.50,	q: 0.25
# building a node2vec model...	number of walks: 166680	average walk length: 19.9493	training time: 34.0752
# valid auc: 0.8175
# node dim: 100,	num_walks: 20,	walk_length: 20,	p: 0.50,	q: 0.50
# building a node2vec model...	number of walks: 166680	average walk length: 19.9612	training time: 34.0579
# valid auc: 0.8153
# node dim: 100,	num_walks: 20,	walk_length: 20,	p: 0.50,	q: 1.25
# building a node2vec model...	number of walks: 166680	average walk length: 19.9678	training time: 33.9278
# valid auc: 0.8063
# node dim: 100,	num_walks: 20,	walk_length: 20,	p: 1.25,	q: 0.25
# building a node2vec model...	number of walks: 166680	average walk length: 19.9294	training time: 34.2059
# valid auc: 0.8161
# node dim: 100,	num_walks: 20,	walk_length: 20,	p: 1.25,	q: 0.50
# building a node2vec model...	number of walks: 166680	average walk length: 19.9484	training time: 34.1276
# valid auc: 0.8151
# node dim: 100,	num_walks: 20,	walk_length: 20,	p: 1.25,	q: 1.25
# building a node2vec model...	number of walks: 166680	average walk length: 19.9644	training time: 34.1994
# valid auc: 0.8041
# node dim: 100,	num_walks: 20,	walk_length: 50,	p: 0.25,	q: 0.25
# building a node2vec model...	number of walks: 166680	average walk length: 49.7554	training time: 63.6829
# valid auc: 0.8233
# node dim: 100,	num_walks: 20,	walk_length: 50,	p: 0.25,	q: 0.50
# building a node2vec model...	number of walks: 166680	average walk length: 49.8110	training time: 63.2338
# valid auc: 0.8177
# node dim: 100,	num_walks: 20,	walk_length: 50,	p: 0.25,	q: 1.25
# building a node2vec model...	number of walks: 166680	average walk length: 49.8502	training time: 63.0340
# valid auc: 0.8045
# node dim: 100,	num_walks: 20,	walk_length: 50,	p: 0.50,	q: 0.25
# building a node2vec model...	number of walks: 166680	average walk length: 49.7126	training time: 63.8520
# valid auc: 0.8268
# node dim: 100,	num_walks: 20,	walk_length: 50,	p: 0.50,	q: 0.50
# building a node2vec model...	number of walks: 166680	average walk length: 49.7531	training time: 63.7562
# valid auc: 0.8203
# node dim: 100,	num_walks: 20,	walk_length: 50,	p: 0.50,	q: 1.25
# building a node2vec model...	number of walks: 166680	average walk length: 49.8300	training time: 63.3727
# valid auc: 0.8105
# node dim: 100,	num_walks: 20,	walk_length: 50,	p: 1.25,	q: 0.25
# building a node2vec model...	number of walks: 166680	average walk length: 49.6398	training time: 63.9004
# valid auc: 0.8261
# node dim: 100,	num_walks: 20,	walk_length: 50,	p: 1.25,	q: 0.50
# building a node2vec model...	number of walks: 166680	average walk length: 49.6941	training time: 63.9086
# valid auc: 0.8238
# node dim: 100,	num_walks: 20,	walk_length: 50,	p: 1.25,	q: 1.25
# building a node2vec model...	number of walks: 166680	average walk length: 49.7712	training time: 63.7950
# valid auc: 0.8133
# node dim: 100,	num_walks: 50,	walk_length: 10,	p: 0.25,	q: 0.25
# building a node2vec model...	number of walks: 416700	average walk length: 9.9906	training time: 59.9904
# valid auc: 0.8304
# node dim: 100,	num_walks: 50,	walk_length: 10,	p: 0.25,	q: 0.50
# building a node2vec model...	number of walks: 416700	average walk length: 9.9912	training time: 59.8087
# valid auc: 0.8295
# node dim: 100,	num_walks: 50,	walk_length: 10,	p: 0.25,	q: 1.25
# building a node2vec model...	number of walks: 416700	average walk length: 9.9919	training time: 59.7052
# valid auc: 0.8201
# node dim: 100,	num_walks: 50,	walk_length: 10,	p: 0.50,	q: 0.25
# building a node2vec model...	number of walks: 416700	average walk length: 9.9886	training time: 60.3382
# valid auc: 0.8295
# node dim: 100,	num_walks: 50,	walk_length: 10,	p: 0.50,	q: 0.50
# building a node2vec model...	number of walks: 416700	average walk length: 9.9905	training time: 60.1574
# valid auc: 0.8275
# node dim: 100,	num_walks: 50,	walk_length: 10,	p: 0.50,	q: 1.25
# building a node2vec model...	number of walks: 416700	average walk length: 9.9908	training time: 59.9328
# valid auc: 0.8201
# node dim: 100,	num_walks: 50,	walk_length: 10,	p: 1.25,	q: 0.25
# building a node2vec model...	number of walks: 416700	average walk length: 9.9828	training time: 60.1093
# valid auc: 0.8288
# node dim: 100,	num_walks: 50,	walk_length: 10,	p: 1.25,	q: 0.50
# building a node2vec model...	number of walks: 416700	average walk length: 9.9878	training time: 60.1349
# valid auc: 0.8265
# node dim: 100,	num_walks: 50,	walk_length: 10,	p: 1.25,	q: 1.25
# building a node2vec model...	number of walks: 416700	average walk length: 9.9906	training time: 60.2882
# valid auc: 0.8192
# node dim: 100,	num_walks: 50,	walk_length: 20,	p: 0.25,	q: 0.25
# building a node2vec model...	number of walks: 416700	average walk length: 19.9620	training time: 83.7347
# valid auc: 0.8383
# node dim: 100,	num_walks: 50,	walk_length: 20,	p: 0.25,	q: 0.50
# building a node2vec model...	number of walks: 416700	average walk length: 19.9657	training time: 83.5400
# valid auc: 0.8345
# node dim: 100,	num_walks: 50,	walk_length: 20,	p: 0.25,	q: 1.25
# building a node2vec model...	number of walks: 416700	average walk length: 19.9697	training time: 83.1122
# valid auc: 0.8227
# node dim: 100,	num_walks: 50,	walk_length: 20,	p: 0.50,	q: 0.25
# building a node2vec model...	number of walks: 416700	average walk length: 19.9492	training time: 83.8386
# valid auc: 0.8407
# node dim: 100,	num_walks: 50,	walk_length: 20,	p: 0.50,	q: 0.50
# building a node2vec model...	number of walks: 416700	average walk length: 19.9621	training time: 83.9444
# valid auc: 0.8366
# node dim: 100,	num_walks: 50,	walk_length: 20,	p: 0.50,	q: 1.25
# building a node2vec model...	number of walks: 416700	average walk length: 19.9687	training time: 84.3093
# valid auc: 0.8267
# node dim: 100,	num_walks: 50,	walk_length: 20,	p: 1.25,	q: 0.25
# building a node2vec model...	number of walks: 416700	average walk length: 19.9289	training time: 83.9999
# valid auc: 0.8409
# node dim: 100,	num_walks: 50,	walk_length: 20,	p: 1.25,	q: 0.50
# building a node2vec model...	number of walks: 416700	average walk length: 19.9476	training time: 84.7986
# valid auc: 0.8396
# node dim: 100,	num_walks: 50,	walk_length: 20,	p: 1.25,	q: 1.25
# building a node2vec model...	number of walks: 416700	average walk length: 19.9639	training time: 83.5998
# valid auc: 0.8304
# node dim: 100,	num_walks: 50,	walk_length: 50,	p: 0.25,	q: 0.25
# building a node2vec model...	number of walks: 416700	average walk length: 49.7587	training time: 158.0321
# valid auc: 0.8342
# node dim: 100,	num_walks: 50,	walk_length: 50,	p: 0.25,	q: 0.50
# building a node2vec model...	number of walks: 416700	average walk length: 49.8101	training time: 157.5495
# valid auc: 0.8280
# node dim: 100,	num_walks: 50,	walk_length: 50,	p: 0.25,	q: 1.25
# building a node2vec model...	number of walks: 416700	average walk length: 49.8544	training time: 156.5639
# valid auc: 0.8163
# node dim: 100,	num_walks: 50,	walk_length: 50,	p: 0.50,	q: 0.25
# building a node2vec model...	number of walks: 416700	average walk length: 49.7110	training time: 158.6755
# valid auc: 0.8379
# node dim: 100,	num_walks: 50,	walk_length: 50,	p: 0.50,	q: 0.50
# building a node2vec model...	number of walks: 416700	average walk length: 49.7619	training time: 157.8052
# valid auc: 0.8331
# node dim: 100,	num_walks: 50,	walk_length: 50,	p: 0.50,	q: 1.25
# building a node2vec model...	number of walks: 416700	average walk length: 49.8290	training time: 157.1974
# valid auc: 0.8221
# node dim: 100,	num_walks: 50,	walk_length: 50,	p: 1.25,	q: 0.25
# building a node2vec model...	number of walks: 416700	average walk length: 49.6359	training time: 158.9712
# valid auc: 0.8395
# node dim: 100,	num_walks: 50,	walk_length: 50,	p: 1.25,	q: 0.50
# building a node2vec model...	number of walks: 416700	average walk length: 49.6977	training time: 158.7131
# valid auc: 0.8353
# node dim: 100,	num_walks: 50,	walk_length: 50,	p: 1.25,	q: 1.25
# building a node2vec model...	number of walks: 416700	average walk length: 49.7730	training time: 158.1686
# valid auc: 0.8274

# %% [markdown]
# Example of using Heatmap to viualize the result.

# %%
plt.figure(figsize=(6, 4))
# node_dim = 10
# you should have an auc score dictionary here.
a = np.array([[node2vec_auc_scores[(node_dim, num_walks_, walk_length_)] for walk_length_ in walk_length] for num_walks_ in num_walks])
plt.imshow(a, cmap="hot", interpolation="nearest")
plt.colorbar()
plt.xticks(ticks=[0,1,2], labels=[10, 20, 40])
plt.xlabel("walk_length")
plt.yticks(ticks=[0,1,2,3], labels=[5, 10, 20, 40])
plt.ylabel("num_walks")

# %%
n = 10
top_n_scores_and_param = sorted(node2vec_auc_scores.items(), key=lambda x: x[1], reverse=True)[:n]
for param, score in top_n_scores_and_param:
    print("node dim: %d,\tnum_walks: %d,\twalk_length: %d,\tp: %.2f,\tq: %.2f,\tvalid auc: %.4f" % (param[0], param[1], param[2], param[3], param[4], score))
# Out:
# node dim: 10,	num_walks: 20,	walk_length: 10,	p: 0.25,	q: 1.25,	valid auc: 0.9315
# node dim: 10,	num_walks: 10,	walk_length: 20,	p: 0.25,	q: 1.25,	valid auc: 0.9314
# node dim: 10,	num_walks: 10,	walk_length: 20,	p: 0.50,	q: 0.50,	valid auc: 0.9313
# node dim: 10,	num_walks: 20,	walk_length: 10,	p: 0.25,	q: 0.50,	valid auc: 0.9313
# node dim: 10,	num_walks: 10,	walk_length: 20,	p: 1.25,	q: 1.25,	valid auc: 0.9311
# node dim: 10,	num_walks: 10,	walk_length: 20,	p: 1.25,	q: 0.50,	valid auc: 0.9310
# node dim: 10,	num_walks: 10,	walk_length: 20,	p: 0.25,	q: 0.50,	valid auc: 0.9307
# node dim: 10,	num_walks: 10,	walk_length: 20,	p: 0.25,	q: 0.25,	valid auc: 0.9307
# node dim: 10,	num_walks: 10,	walk_length: 20,	p: 0.50,	q: 1.25,	valid auc: 0.9307
# node dim: 10,	num_walks: 10,	walk_length: 20,	p: 1.25,	q: 0.25,	valid auc: 0.9306

# %% [markdown]
# You can build model with the best parameters you find and save the prediction here.

# %%
best_param = top_n_scores_and_param[0][0]
alias_nodes, alias_edges = preprocess_transition_probs(graph, p=best_param[3], q=best_param[4])
model = build_node2vec(graph, alias_nodes, alias_edges, node_dim=best_param[0], num_walks=best_param[1], walk_length=best_param[2])
scores = [get_cosine_sim(model, src, dst) for src, dst in test_edges]
# write_pred("data/pred.csv", test_edges, scores)
# Out:
# building a node2vec model...	number of walks: 166680	average walk length: 9.9925	training time: 23.8828

# %% [markdown]
# With the help of p and q, the node2vec model can fit training data better. And you can have a try if you set p=q=1, the two models will return the same results.
